# %% [markdown]
# # File Listing (Self Learning Exercise)

# %%
import os
start=os.path.expanduser('~')
for root,dirs,files in os.walk(start):
    for f in files:
        try:
            print(os.path.join(root,f))
        except:
            pass
# Out:
# Streaming output truncated to the last 5000 lines.
# /root/.julia/compiled/v1.11/Unzip/6rOOd_0abgj.ji
# /root/.julia/compiled/v1.11/Unzip/6rOOd_0abgj.so
# /root/.julia/compiled/v1.11/EnumX/yh1Fz_0abgj.so
# /root/.julia/compiled/v1.11/EnumX/yh1Fz_0abgj.ji
# /root/.julia/compiled/v1.11/LERC_jll/0PXNr_0abgj.so
# /root/.julia/compiled/v1.11/LERC_jll/0PXNr_0abgj.ji
# /root/.julia/compiled/v1.11/libfdk_aac_jll/Ido5Q_0abgj.so
# /root/.julia/compiled/v1.11/libfdk_aac_jll/Ido5Q_0abgj.ji
# /root/.julia/compiled/v1.11/RatiosFixedPointNumbersExt/R2tFd_0abgj.so
# /root/.julia/compiled/v1.11/RatiosFixedPointNumbersExt/R2tFd_0abgj.ji
# /root/.julia/compiled/v1.11/RelocatableFolders/Yg3O9_0abgj.ji
# /root/.julia/compiled/v1.11/RelocatableFolders/Yg3O9_0abgj.so
# /root/.julia/compiled/v1.11/EarCut_jll/SRVPx_0abgj.so
# /root/.julia/compiled/v1.11/EarCut_jll/SRVPx_0abgj.ji
# /root/.julia/compiled/v1.11/IrrationalConstants/ukdUG_0abgj.so
# /root/.julia/compiled/v1.11/IrrationalConstants/ukdUG_0abgj.ji
# ...
